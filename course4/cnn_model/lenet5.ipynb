# %%
import tensorflow as tf
from tensorflow import keras

# %%
def build_model(input_shape=(32,32,1), num_classes=10):
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(filters=6, kernel_size=(5, 5), padding='valid', activation='tanh', input_shape=input_shape),
        tf.keras.layers.AveragePooling2D(pool_size=(2, 2)),

        tf.keras.layers.Conv2D(filters=16, kernel_size=(5, 5), strides=1, padding='valid', activation='tanh'),
        tf.keras.layers.AveragePooling2D(pool_size=(2, 2)),

        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(units=120, activation='tanh'),

        tf.keras.layers.Dense(units=84, activation='tanh'),

        tf.keras.layers.Dense(units=num_classes, activation='softmax')
    ])

    return model

# %%
lenet5 = build_model()
lenet5.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_21 (Conv2D)          (None, 28, 28, 6)         156
#
#  average_pooling2d_14 (Avera  (None, 14, 14, 6)        0
#  gePooling2D)
#
#  conv2d_22 (Conv2D)          (None, 10, 10, 16)        2416
#
#  average_pooling2d_15 (Avera  (None, 5, 5, 16)         0
#  gePooling2D)
#
#  flatten_9 (Flatten)         (None, 400)               0
#
#  dense_31 (Dense)            (None, 120)               48120
#
#  dense_32 (Dense)            (None, 84)                10164
#
#  dense_33 (Dense)            (None, 10)                850
#
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
def identity_block(x, filters, kernel_size=3):
    """Identity Block của ResNet"""
    f1, f2, f3 = filters

    x_shortcut = x

    # Tầng Convolutional đầu tiên
    x = tf.keras.layers.Conv2D(f1, kernel_size=(1, 1), strides=(1, 1), padding='valid')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)

    # Tầng Convolutional thứ hai
    x = tf.keras.layers.Conv2D(f2, kernel_size=(kernel_size, kernel_size), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)

    # Tầng Convolutional thứ ba
    x = tf.keras.layers.Conv2D(f3, kernel_size=(1, 1), strides=(1, 1), padding='valid')(x)
    x = tf.keras.layers.BatchNormalization()(x)

    # Kết hợp với đầu vào
    x = tf.keras.layers.Add()([x, x_shortcut])
    x = tf.keras.layers.Activation('relu')(x)

    return x

def convolutional_block(x, filters, kernel_size=3, strides=2):
    """Convolutional Block của ResNet"""
    f1, f2, f3 = filters

    x_shortcut = x

    # Tầng Convolutional đầu tiên
    x = tf.keras.layers.Conv2D(f1, kernel_size=(1, 1), strides=(strides, strides), padding='valid')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)

    # Tầng Convolutional thứ hai
    x = tf.keras.layers.Conv2D(f2, kernel_size=(kernel_size, kernel_size), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)

    # Tầng Convolutional thứ ba
    x = tf.keras.layers.Conv2D(f3, kernel_size=(1, 1), strides=(1, 1), padding='valid')(x)
    x = tf.keras.layers.BatchNormalization()(x)

    # Tầng Shortcut
    x_shortcut = tf.keras.layers.Conv2D(f3, kernel_size=(1, 1), strides=(strides, strides), padding='valid')(x_shortcut)
    x_shortcut = tf.keras.layers.BatchNormalization()(x_shortcut)

    # Kết hợp với đầu vào
    x = tf.keras.layers.Add()([x, x_shortcut])
    x = tf.keras.layers.Activation('relu')(x)

    return x

def ResNet50(input_shape=(224, 224, 3), num_classes=1000):
    """Xây dựng mô hình ResNet-50"""

    input_tensor = tf.keras.layers.Input(shape=input_shape)

    # Tầng đầu tiên
    x = tf.keras.layers.ZeroPadding2D(padding=(3, 3))(input_tensor)
    x = tf.keras.layers.Conv2D(64, kernel_size=(7, 7), strides=(2, 2), padding='valid')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='valid')(x)

    # Các Blocks
    x = convolutional_block(x, filters=[64, 64, 256], strides=1)
    x = identity_block(x, filters=[64, 64, 256])
    x = identity_block(x, filters=[64, 64, 256])

    x = convolutional_block(x, filters=[128, 128, 512])
    x = identity_block(x, filters=[128, 128, 512])
    x = identity_block(x, filters=[128, 128, 512])
    x = identity_block(x, filters=[128, 128, 512])

    x = convolutional_block(x, filters=[256, 256, 1024])
    x = identity_block(x, filters=[256, 256, 1024])
    x = identity_block(x, filters=[256, 256, 1024])
    x = identity_block(x, filters=[256, 256, 1024])
    x = identity_block(x, filters=[256, 256, 1024])

    x = convolutional_block(x, filters=[512, 512, 2048])
    x = identity_block(x, filters=[512, 512, 2048])
    x = identity_block(x, filters=[512, 512, 2048])

    # Tầng Global Average Pooling
    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Tầng Fully Connected
    x = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs=input_tensor, outputs=x)

    return model

# Tạo mô hình
resnet50_model = ResNet50()
resnet50_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0          ['input_2[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 112, 112, 64  9472        ['zero_padding2d[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  256        ['conv2d_23[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 112, 112, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 55, 55, 64)  0           ['activation[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 55, 55, 64)   4160        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 55, 55, 64)  256         ['conv2d_24[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 55, 55, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 55, 55, 64)   36928       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 55, 55, 64)  256         ['conv2d_25[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 55, 55, 64)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 55, 55, 256)  16640       ['activation_2[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 55, 55, 256)  16640       ['max_pooling2d_4[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 55, 55, 256)  1024       ['conv2d_26[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 55, 55, 256)  1024       ['conv2d_27[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 55, 55, 256)  0           ['batch_normalization_3[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  activation_3 (Activation)      (None, 55, 55, 256)  0           ['add[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 55, 55, 64)   16448       ['activation_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 55, 55, 64)  256         ['conv2d_28[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 55, 55, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 55, 55, 64)   36928       ['activation_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 55, 55, 64)  256         ['conv2d_29[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 55, 55, 64)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 55, 55, 256)  16640       ['activation_5[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 55, 55, 256)  1024       ['conv2d_30[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 55, 55, 256)  0           ['batch_normalization_7[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 55, 55, 256)  0           ['add_1[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 55, 55, 64)   16448       ['activation_6[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 55, 55, 64)  256         ['conv2d_31[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 55, 55, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 55, 55, 64)   36928       ['activation_7[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 55, 55, 64)  256         ['conv2d_32[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 55, 55, 64)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 55, 55, 256)  16640       ['activation_8[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 55, 55, 256)  1024       ['conv2d_33[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 55, 55, 256)  0           ['batch_normalization_10[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 55, 55, 256)  0           ['add_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 28, 28, 128)  32896       ['activation_9[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 28, 28, 128)  512        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_10[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 28, 28, 128)  512        ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_11[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 28, 28, 512)  131584      ['activation_9[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_37[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_13[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  activation_12 (Activation)     (None, 28, 28, 512)  0           ['add_3[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 28, 28, 128)  65664       ['activation_12[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 28, 28, 128)  512        ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_13[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 28, 28, 128)  512        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_14[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_40[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_17[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 28, 28, 512)  0           ['add_4[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 28, 28, 128)  65664       ['activation_15[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 28, 28, 128)  512        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_16[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 28, 28, 128)  512        ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_17[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_43[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_20[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 28, 28, 512)  0           ['add_5[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 28, 28, 128)  65664       ['activation_18[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 28, 28, 128)  512        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_19[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 28, 28, 128)  512        ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_20[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_46[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_23[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_21 (Activation)     (None, 28, 28, 512)  0           ['add_6[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 14, 14, 256)  131328      ['activation_21[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_22[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_23[0][0]']
#                                 )
#
#  conv2d_50 (Conv2D)             (None, 14, 14, 1024  525312      ['activation_21[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_49[0][0]']
#  ormalization)                  )
#
#  batch_normalization_27 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_50[0][0]']
#  ormalization)                  )
#
#  add_7 (Add)                    (None, 14, 14, 1024  0           ['batch_normalization_26[0][0]',
#                                 )                                 'batch_normalization_27[0][0]']
#
#  activation_24 (Activation)     (None, 14, 14, 1024  0           ['add_7[0][0]']
#                                 )
#
#  conv2d_51 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_24[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_25[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_26[0][0]']
#                                 )
#
#  batch_normalization_30 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_53[0][0]']
#  ormalization)                  )
#
#  add_8 (Add)                    (None, 14, 14, 1024  0           ['batch_normalization_30[0][0]',
#                                 )                                 'activation_24[0][0]']
#
#  activation_27 (Activation)     (None, 14, 14, 1024  0           ['add_8[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_27[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_28[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_32[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_29[0][0]']
#                                 )
#
#  batch_normalization_33 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_56[0][0]']
#  ormalization)                  )
#
#  add_9 (Add)                    (None, 14, 14, 1024  0           ['batch_normalization_33[0][0]',
#                                 )                                 'activation_27[0][0]']
#
#  activation_30 (Activation)     (None, 14, 14, 1024  0           ['add_9[0][0]']
#                                 )
#
#  conv2d_57 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_30[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_31[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_32[0][0]']
#                                 )
#
#  batch_normalization_36 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_59[0][0]']
#  ormalization)                  )
#
#  add_10 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_36[0][0]',
#                                 )                                 'activation_30[0][0]']
#
#  activation_33 (Activation)     (None, 14, 14, 1024  0           ['add_10[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_33[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_37[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_34[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_38[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_35[0][0]']
#                                 )
#
#  batch_normalization_39 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_62[0][0]']
#  ormalization)                  )
#
#  add_11 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_39[0][0]',
#                                 )                                 'activation_33[0][0]']
#
#  activation_36 (Activation)     (None, 14, 14, 1024  0           ['add_11[0][0]']
#                                 )
#
#  conv2d_63 (Conv2D)             (None, 7, 7, 512)    524800      ['activation_36[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_63[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_40[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_37[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_64[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_41[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 7, 7, 2048)   1050624     ['activation_38[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 7, 7, 2048)   2099200     ['activation_36[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_65[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_66[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_42[0][0]',
#                                                                   'batch_normalization_43[0][0]']
#
#  activation_39 (Activation)     (None, 7, 7, 2048)   0           ['add_12[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 7, 7, 512)    1049088     ['activation_39[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_67[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_44[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_40[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_68[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_45[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 7, 7, 2048)   1050624     ['activation_41[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_69[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_46[0][0]',
#                                                                   'activation_39[0][0]']
#
#  activation_42 (Activation)     (None, 7, 7, 2048)   0           ['add_13[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 7, 7, 512)    1049088     ['activation_42[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_70[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_47[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_43[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_71[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_48[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 7, 7, 2048)   1050624     ['activation_44[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_72[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_49[0][0]',
#                                                                   'activation_42[0][0]']
#
#  activation_45 (Activation)     (None, 7, 7, 2048)   0           ['add_14[0][0]']
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['activation_45[0][0]']
#  alAveragePooling2D)
#
#  dense_34 (Dense)               (None, 1000)         2049000     ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 24,514,920
# Trainable params: 24,464,872
# Non-trainable params: 50,048
# __________________________________________________________________________________________________
